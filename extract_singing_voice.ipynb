# %% [markdown]
# <a href="https://colab.research.google.com/github/taro-masuda/singing_voice_recommendation/blob/master/extract_singing_voice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install spleeter

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
pip install spleeter

# %%
from IPython.display import Audio

# %% [markdown]
# # Separate from command line

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls "drive/My Drive/Colab Notebooks/spotify/input"
# Out:
# all_tracks.csv	track_mels  tracks  tracks_sv

# %%
import glob
file_list = glob.glob("drive/My Drive/Colab Notebooks/spotify/input/tracks/*.mp3")
for filename in file_list:
  # !spleeter separate -i "$filename" -o "drive/My Drive/Colab Notebooks/spotify/input/tracks_sv/"
# Out:
# INFO:spleeter:Downloading model archive https://github.com/deezer/spleeter/releases/download/v1.4.0/2stems.tar.gz
# INFO:spleeter:Validating archive checksum
# INFO:spleeter:Extracting downloaded 2stems archive
# INFO:spleeter:2stems model file(s) extracted
# INFO:spleeter:File drive/My Drive/Colab Notebooks/spotify/input/tracks_sv/67HnklgvnucBI6Azx6lV5O/vocals.wav written
# INFO:spleeter:File drive/My Drive/Colab Notebooks/spotify/input/tracks_sv/67HnklgvnucBI6Azx6lV5O/accompaniment.wav written
# INFO:spleeter:File drive/My Drive/Colab Notebooks/spotify/input/tracks_sv/7hjZPeA13HBpkkQw9Hzrqe/accompaniment.wav written
# INFO:spleeter:File drive/My Drive/Colab Notebooks/spotify/input/tracks_sv/7hjZPeA13HBpkkQw9Hzrqe/vocals.wav written
# INFO:spleeter:File drive/My Drive/Colab Notebooks/spotify/input/tracks_sv/0LXJ38MncJmqqVdeUhDIZv/accompaniment.wav written
# INFO:spleeter:File drive/My Drive/Colab Notebooks/spotify/input/tracks_sv/0LXJ38MncJmqqVdeUhDIZv/vocals.wav written
# ...
